# %%
import numpy as np
import pandas as pd
import lasagne
import theano
import theano.tensor as T
import random
import time
import connect_four as cccc
#import seaborn
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# C:\Users\todds\Anaconda2\lib\site-packages\theano\tensor\signal\downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
#initialization

net = []
activation = lasagne.nonlinearities.tanh

hidden_units = 16
num_nets = 10

for i in range(num_nets)
    value_in = lasagne.layers.InputLayer(shape=(None,42))

    value_hid1 = lasagne.layers.DenseLayer(value_in, num_units=hidden_units,W=lasagne.init.GlorotUniform(),
                                              nonlinearity = activation)
    value_hid2 = lasagne.layers.DenseLayer(value_hid1, num_units=hidden_units,W=lasagne.init.GlorotUniform(),
                                              nonlinearity = activation)

    value_hid3 = lasagne.layers.DenseLayer(value_hid2, num_units=hidden_units,W=lasagne.init.GlorotUniform(),
                                              nonlinearity = activation)

    value_hid4 = lasagne.layers.DenseLayer(value_hid3, num_units=hidden_units,W=lasagne.init.GlorotUniform(),
                                              nonlinearity = activation)

    value_hid5 = lasagne.layers.DenseLayer(value_hid4, num_units=hidden_units,W=lasagne.init.GlorotUniform(),
                                              nonlinearity = activation)

    value_hid6 = lasagne.layers.DenseLayer(value_hid5, num_units=hidden_units,W=lasagne.init.GlorotUniform(),
                                              nonlinearity = activation)

    value_drop1 = lasagne.layers.DropoutLayer(value_hid6,p=0.5)

    value_out = lasagne.layers.DenseLayer(value_drop1,
                                      num_units=1, nonlinearity = activation)
    net.append(value_out)


# policy_in = lasagne.layers.InputLayer(shape=(1,9))

# #l_drop1 = lasagne.layers.DropoutLayer(l_shape,p=0.2)

# policy_hid1 = lasagne.layers.DenseLayer(policy_in, num_units=hidden_units,W=lasagne.init.GlorotUniform(),
#                                           nonlinearity = lasagne.nonlinearities.rectify)

# #l_drop2 = lasagne.layers.DropoutLayer(l_hid1,p=0.5)

# policy_out = lasagne.layers.DenseLayer(policy_hid1,
#                                   num_units=9,
#                                   nonlinearity=lasagne.nonlinearities.softmax)
# Out:
#   File "<ipython-input-2-6e1f5ca786b1>", line 9
#     for i in range(num_nets)
#                             ^
# SyntaxError: invalid syntax

# %%
def value_move(board,active_turn,output_fun,exploration = 0):
    board = board.reshape((1,42))
    X_sym = theano.tensor.matrix()
    y_sym = theano.tensor.ivector()

    dummy_board = active_turn * board[:]
    options = cccc.available_moves(dummy_board)
    
    
    if exploration > random.random():
        move = random.choice(options) 
    else:
        move_values = np.zeros(42)
        for move in options:
            dummy_board = active_turn * board[:]
            dummy_board[0][move] = 1
            move_values[move] = -1 * output_fun(-1* dummy_board)
        

        available_move_values = np.array([move_values[move] for move in options])
        
        move = options[available_move_values.argmax(-1)]
    return move + 1


class nn_ai:
    
    def __init__(self,output_fun, net = 'value',exploration = 0):
        self.output_fun = output_fun
        self.exploration = exploration
        self.net = net
    
    def make_move(self,board,active_turn):
#         if self.net == 'policy':
#             move = policy_move(board,active_turn,self.output_fun,self.exploration)
        if self.net == 'value':
            move = value_move(board,active_turn,self.output_fun,self.exploration)
        return move
    
def alpha_beta_move(board,active_turn,depth,alpha = 2):
    swap_dict = {1:-1,-1:1}
    dummy_board = np.zeros((6,7))
    dummy_board[:] = board[:]
    options = cccc.available_moves(board)
    random.shuffle(options)
    if len(options) == 1:
        dummy_board[np.where(dummy_board[:,options[0]]==0)[0][-1],options[0]] = active_turn
        if cccc.winner(dummy_board):
            return (1,options[0]+1)
        else:
            return (0,options[0]+1)
    if depth ==0:
        return (0, options[np.random.randint(len(options))]+1)

    best_value = -2
    candidate_move = None
    for x in options:
        height = np.where(dummy_board[:,x]==0)[0][-1]
        dummy_board[height,x] = active_turn
        if cccc.winner(dummy_board):
            return (1, x+1)
        (opp_value,opp_move) = alpha_beta_move(dummy_board,swap_dict[active_turn],depth-1,-best_value)
        if -opp_value > best_value:
            candidate_move = x+1
            best_value = -opp_value
        if -opp_value >= alpha:
            #print (options, x, best_value, alpha)
            break
        dummy_board[height,x] = 0

    return (best_value, candidate_move)

class alpha_beta:
    def __init__(self,depth):
        self.depth = depth
    def make_move(self,board,active_turn):
        #print (board,active_turn,self.depth)
        return alpha_beta_move(board,active_turn,self.depth)[1]

def get_max_future(future_board,value_fun):
    options = cccc.available_moves(future_board)
    dummy_board = np.copy(future_board)
    move_values = np.zeros(7)
    for move in options:
        dummy_board = np.copy(future_board)
        dummy_board[np.where(dummy_board[:,move]==0)[0][-1],move] = -1
        # dummy_board = dummy_board.reshape(1,42)
        if cccc.winner(dummy_board):
            move_values[move] = cccc.winner(dummy_board)
        else:
            reshapable = np.copy(dummy_board)
            reshapable = reshapable.reshape(1,42)
            move_values[move] = value_fun(reshapable)
    
    available_move_values = np.array([move_values[move] for move in options])
    dummy_board = np.copy(future_board)
    options_index = np.argmin(available_move_values)
    dummy_board[np.where(dummy_board[:,options[options_index]]==0)[0][-1],options[options_index]] = -1
    return np.amin(available_move_values), dummy_board

def play_one_move(current_board,value_fun,exploration = 0):
    options = cccc.available_moves(current_board)
    dummy_board = np.copy(current_board)
    move_values = np.zeros(7)
    if np.random.random() < exploration:
        chosen_move = random.choice(options)
        dummy_board[np.where(dummy_board[:,chosen_move]==0)[0][-1],chosen_move] = 1
        if cccc.winner(dummy_board):
            value = cccc.winner(dummy_board)
        else:
            reshapable = np.copy(dummy_board)
            reshapable = reshapable.reshape(1,42)
            value = -1 * value_fun(-1 * reshapable)
    else:
    
        for move in options:
            dummy_board = np.copy(current_board)
            dummy_board[np.where(dummy_board[:,move]==0)[0][-1],move] = 1
            # dummy_board = dummy_board.reshape(1,42)
            if cccc.winner(dummy_board):
                move_values[move] = cccc.winner(dummy_board)
            else:
                reshapable = np.copy(dummy_board)
                reshapable = reshapable.reshape(1,42)
                move_values[move] = -1 * value_fun(-1 * reshapable)
    
        available_move_values = np.array([move_values[move] for move in options])
        dummy_board = np.copy(current_board)
        options_index = np.argmax(available_move_values)
        dummy_board[np.where(dummy_board[:,options[options_index]]==0)[0][-1],options[options_index]] = 1
        value = np.amax(available_move_values)
        
    return value , dummy_board

def get_inputs(log):
    boards = []
    piece = 1
    board = np.zeros((6,7))
    boards.append(np.copy(board))
    for move in log:
        board[np.where(board[:,move-1]==0)[0][-1],move-1] = piece
        piece = -piece
        boards.append(np.copy(board))
    return boards



def game_over(board):
    return cccc.winner(board) or cccc.is_full(board)

# %% [markdown]
# # Reinforcement Learning

# %%
X_sym = T.matrix()
y_sym = T.matrix()

input_history = []
output_history = []
results = {}
move_history = []
output = lasagne.layers.get_output(value_out,X_sym)
output_det = lasagne.layers.get_output(value_out,X_sym,deterministic=True)
value_fun = theano.function([X_sym],output)
value_fun_det = theano.function([X_sym],output_det)
params = lasagne.layers.get_all_params(value_out)
objective = T.mean(lasagne.objectives.squared_error(output,y_sym))
grad = T.grad(objective,params)
self_play = 0

#flush training sets
input_history = []
output_history = []
results = {}
move_history = []

# %%
BATCH_SIZE = 256
batches_per_step = 10
training_per_step =0
train_duration = 10000
exploration = 0.25
exploration_min = 0.10
exploration_step = 0.999
future_discount = 0.5
minimax_str = 0
validation_str = 0
monte_carlo_duration = 0
print_freq = batches_per_step-1
valid_freq = 10
learning_speed = 0.01
updates = lasagne.updates.nesterov_momentum(grad, params, learning_rate=learning_speed,momentum = 0.9)
#updates = lasagne.updates.sgd(grad, params, learning_rate=learning_speed)
train_net = theano.function([X_sym, y_sym], objective, updates=updates)
temporal_index = 0.8
objective_total = 1000.0

# %%
param_values = lasagne.layers.get_all_param_values(value_out)
training_size = 3 * sum([param_values[i].size for i,_ in enumerate(param_values)])
for item in param_values:
    print item.shape
    
print training_size
# Out:
# (42L, 16L)
# (16L,)
# (16L, 16L)
# (16L,)
# (16L, 16L)
# (16L,)
# (16L, 16L)
# (16L,)
# (16L, 16L)
# (16L,)
# (16L, 16L)
# (16L,)
# (16L, 1L)
# (1L,)
# 6195

# %%
t0 = time.clock()
epoch_objective_list = []

param_values = lasagne.layers.get_all_param_values(value_out)
training_size = 3 * sum([param_values[i].size for i,_ in enumerate(param_values)])

training_data = [0]*training_size
target_data = [0]*training_size

current_write_index = 0

            
    
print 'Creating Targets for {} data points'.format(training_size)
print '\n'

#initialize training set

while(current_write_index < training_size):
    
    current_state = cccc.empty_board()
    player = 1
    self_play +=1
    board_history = []
    value_history = []
    while not game_over(np.copy(current_state)):
        current_value , next_state = play_one_move(current_state,value_fun,exploration)
        board_history.append(current_state)
        value_history.append(current_value)

        
        current_state = -1 * np.copy(next_state)
        player *= -1
    

    board_history.append(current_state)
    value_history.append(cccc.winner(current_state))
    
    # record the targets
    training_data[current_write_index%training_size] = board_history.pop(-1)
    target_data[current_write_index%training_size] = value_history.pop(-1)
    last_target = target_data[current_write_index%training_size]
    current_write_index += 1
    
    while board_history:

        training_data[current_write_index%training_size] = board_history.pop(-1)
        target_data[current_write_index%training_size] = (
            1 - temporal_index) * value_history.pop(-1) - temporal_index * last_target
        last_target = target_data[current_write_index%training_size]
        current_write_index += 1

print 'Targets took {}s to create'.format(time.clock()-t0)
    
# start training

data_generation = 0
for epoch in range(train_duration):
    
    t1 = time.clock()
    exploration = (exploration-exploration_min)* exploration_step + exploration_min
    if current_write_index >= training_size:
        data_generation +=1
        print '\n'
        print 'now starting generation {} of data'.format(data_generation)
        print '\n'
    current_write_index = current_write_index%training_size
    
    # continue to update training set
#     for _ in range(training_size/50):
    counter = 0
    while(counter < training_size):
    
    
        current_state = cccc.empty_board()
        player = 1
        self_play +=1
        board_history = []
        value_history = []
        while not game_over(np.copy(current_state)):
            current_value , next_state = play_one_move(current_state,value_fun,exploration)
            board_history.append(current_state)
            value_history.append(current_value)


            current_state = -1 * np.copy(next_state)
            player *= -1


        board_history.append(current_state)
        value_history.append(cccc.winner(current_state))

        # record the targets
        training_data[current_write_index%training_size] = board_history.pop(-1)
        target_data[current_write_index%training_size] = value_history.pop(-1)
        last_target = target_data[current_write_index%training_size]
        current_write_index += 1
        counter +=1

        while board_history:

            training_data[current_write_index%training_size] = board_history.pop(-1)
            target_data[current_write_index%training_size] = (
                1 - temporal_index) * value_history.pop(-1) - temporal_index * last_target
            last_target = target_data[current_write_index%training_size]
            current_write_index += 1
            counter +=1
        
        
    for j in range(batches_per_step):
        t2=time.clock()
        targets = np.zeros((BATCH_SIZE,1))
        training = np.zeros((BATCH_SIZE,42))
        index_pool = range(training_size)
        random.shuffle(index_pool)
        objectives = []        

        while len(index_pool) > BATCH_SIZE:
            sample_indices = [index_pool.pop() for _ in xrange(BATCH_SIZE)]
            #Should try to use generators


            for k in range(BATCH_SIZE):
                #train it on output_history evaluated by the opponent
                training[k] = training_data[sample_indices[k]].reshape(1,42)
                targets[k] = target_data[sample_indices[k]]



            objectives.append(train_net(training,targets))
            #break to only do 1 batch per run.
        objective_total = np.mean(objectives)
    
    
        if j % print_freq ==0:
            print (('Epoch {:5d}, Pass number {}, objective: {:0.5f}, exploration: {:0.2f}, '+
                   'number of games played: {}, step duration: {:1.3f}s').format(
                   epoch,j+1,float(objective_total),exploration,self_play,time.clock()-t2))


        epoch_objective_list.append([epoch,j+1,objective_total,exploration])


    print 'epoch duration {:2.2f}s'.format(time.clock()-t1)
    if epoch%valid_freq==0 or epoch == valid / 5 * 4:
        print ' '
        print ' '
        test_result = {'wins':0,'ties':0,'losses':0}
        for j in range(100):
            result = cccc.play(nn_ai(value_fun_det,'value'),alpha_beta(validation_str))
            if result.winner ==1:
                test_result['wins'] +=1
            if result.winner == 0:
                test_result['ties'] +=1
            if result.winner == -1:
                test_result['losses'] +=1


        print 'As X, neural network has a score of {:3d}-{:3d}-{:3d} vs {}-depth minimax'.format(test_result['wins'],
                                                               test_result['ties'],test_result['losses'],validation_str)

        test_result = {'wins':0,'ties':0,'losses':0}

        for j in range(100):
            result = cccc.play(alpha_beta(validation_str),nn_ai(value_fun_det,'value'))
            if result.winner ==1:
                test_result['losses'] +=1
            if result.winner == 0:
                test_result['ties'] +=1
            if result.winner == -1:
                test_result['wins'] +=1

        print 'As O, neural network has a score of {:3d}-{:3d}-{:3d} vs {}-depth minimax'.format(test_result['wins'],
                                                            test_result['ties'],test_result['losses'],validation_str)
        print ' '
        print 'elapsed time: {:3.3f}s'.format(time.clock()-t0)
        print ' '
        # save the chromes
        np.savez('TD_cccc_last',lasagne.layers.get_all_param_values(value_out))


print('\n')

#for epoch in range(10):

        
#    t_epoch = time.clock()

#    result_list = [tourney(output) for i in range(BATCH_SIZE)]
#    fitness_list = [fitness(result) for result in result_list]
    
#    score= f_train(fitness_list)
       
#    t1=time.clock()-t_epoch
    
#    print('Epoch {}, duration {:.01f} seconds'.format(
#            epoch+1, t1))
#    print('Record is: {}-{}-{} with a score of {}'.format(sum([result['wins'] for result in result_list]),
#                                                          sum([result['ties'] for result in result_list]),
#                                                          sum([result['losses'] for result in result_list]),
#                                                          sum([fitness for fitness in fitness_list])))
#    print('mean score is {}'.format(score))
print('total time for neural network is {:.01f} seconds'.format(time.clock()-t0))
# Out:
# Creating Targets for 6195 data points
#
#
# Targets took 10.2518242213s to create
#
#
# now starting generation 1 of data
#
#
# Epoch     0, Pass number 1, objective: 0.26121, exploration: 0.25, number of games played: 736, step duration: 0.052s
# Epoch     0, Pass number 10, objective: 0.17187, exploration: 0.25, number of games played: 736, step duration: 0.047s
# epoch duration 10.70s
#
#
# As X, neural network has a score of  71-  0- 29 vs 0-depth minimax
# As O, neural network has a score of  37-  0- 63 vs 0-depth minimax
#
# elapsed time: 22.850s
#
#
#
# now starting generation 2 of data
#
#
# Epoch     1, Pass number 1, objective: 0.24456, exploration: 0.25, number of games played: 1096, step duration: 0.055s
# Epoch     1, Pass number 10, objective: 0.16587, exploration: 0.25, number of games played: 1096, step duration: 0.046s
# epoch duration 11.04s
#
#
# now starting generation 3 of data
#
#
# Epoch     2, Pass number 1, objective: 0.23010, exploration: 0.25, number of games played: 1460, step duration: 0.049s
# Epoch     2, Pass number 10, objective: 0.16321, exploration: 0.25, number of games played: 1460, step duration: 0.061s
# epoch duration 10.99s
#
#
# now starting generation 4 of data
#
#
# Epoch     3, Pass number 1, objective: 0.23664, exploration: 0.25, number of games played: 1825, step duration: 0.041s
# Epoch     3, Pass number 10, objective: 0.16914, exploration: 0.25, number of games played: 1825, step duration: 0.045s
# epoch duration 11.06s
#
#
# now starting generation 5 of data
#
#
# Epoch     4, Pass number 1, objective: 0.23320, exploration: 0.25, number of games played: 2188, step duration: 0.048s
# Epoch     4, Pass number 10, objective: 0.16237, exploration: 0.25, number of games played: 2188, step duration: 0.059s
# epoch duration 10.94s
#
#
# now starting generation 6 of data
#
#
# Epoch     5, Pass number 1, objective: 0.23908, exploration: 0.25, number of games played: 2537, step duration: 0.049s
# Epoch     5, Pass number 10, objective: 0.18198, exploration: 0.25, number of games played: 2537, step duration: 0.053s
# epoch duration 10.98s
#
#
# now starting generation 7 of data
#
#
# Epoch     6, Pass number 1, objective: 0.21665, exploration: 0.25, number of games played: 2905, step duration: 0.044s
# Epoch     6, Pass number 10, objective: 0.14843, exploration: 0.25, number of games played: 2905, step duration: 0.053s
# epoch duration 10.87s
#
#
# now starting generation 8 of data
#
#
# Epoch     7, Pass number 1, objective: 0.22351, exploration: 0.25, number of games played: 3258, step duration: 0.042s
# Epoch     7, Pass number 10, objective: 0.16955, exploration: 0.25, number of games played: 3258, step duration: 0.041s
# epoch duration 11.10s
#
#
# now starting generation 9 of data
#
#
# Epoch     8, Pass number 1, objective: 0.22357, exploration: 0.25, number of games played: 3675, step duration: 0.048s
# Epoch     8, Pass number 10, objective: 0.15343, exploration: 0.25, number of games played: 3675, step duration: 0.046s
# epoch duration 10.85s
#
#
# now starting generation 10 of data
#
#
# Epoch     9, Pass number 1, objective: 0.21344, exploration: 0.25, number of games played: 4045, step duration: 0.042s
# Epoch     9, Pass number 10, objective: 0.14806, exploration: 0.25, number of games played: 4045, step duration: 0.056s
# epoch duration 10.91s
#
#
# now starting generation 11 of data
#
#
# Epoch    10, Pass number 1, objective: 0.21771, exploration: 0.25, number of games played: 4401, step duration: 0.044s
# Epoch    10, Pass number 10, objective: 0.15226, exploration: 0.25, number of games played: 4401, step duration: 0.049s
# epoch duration 10.90s
#
#
# As X, neural network has a score of  74-  0- 26 vs 0-depth minimax
# As O, neural network has a score of  60-  0- 40 vs 0-depth minimax
#
# elapsed time: 134.498s
#
#
#
# now starting generation 12 of data
#
#
# Epoch    11, Pass number 1, objective: 0.23183, exploration: 0.25, number of games played: 4757, step duration: 0.041s
# Epoch    11, Pass number 10, objective: 0.16291, exploration: 0.25, number of games played: 4757, step duration: 0.041s
# epoch duration 10.97s
#
#
# now starting generation 13 of data
#
#
# Epoch    12, Pass number 1, objective: 0.23679, exploration: 0.25, number of games played: 5141, step duration: 0.046s
# Epoch    12, Pass number 10, objective: 0.16207, exploration: 0.25, number of games played: 5141, step duration: 0.052s
# epoch duration 11.00s
#
#
# now starting generation 14 of data
#
#
# Epoch    13, Pass number 1, objective: 0.23832, exploration: 0.25, number of games played: 5513, step duration: 0.042s
# Epoch    13, Pass number 10, objective: 0.16224, exploration: 0.25, number of games played: 5513, step duration: 0.049s
# epoch duration 11.08s
#
#
# now starting generation 15 of data
#
#
# Epoch    14, Pass number 1, objective: 0.21369, exploration: 0.25, number of games played: 5855, step duration: 0.043s
# Epoch    14, Pass number 10, objective: 0.15305, exploration: 0.25, number of games played: 5855, step duration: 0.047s
# epoch duration 10.84s
#
#
# now starting generation 16 of data
#
#
# Epoch    15, Pass number 1, objective: 0.22420, exploration: 0.25, number of games played: 6215, step duration: 0.047s
# Epoch    15, Pass number 10, objective: 0.15325, exploration: 0.25, number of games played: 6215, step duration: 0.061s
# epoch duration 10.99s
#
#
# now starting generation 17 of data
#
#
# Epoch    16, Pass number 1, objective: 0.23878, exploration: 0.25, number of games played: 6585, step duration: 0.049s
# Epoch    16, Pass number 10, objective: 0.16584, exploration: 0.25, number of games played: 6585, step duration: 0.042s
# epoch duration 10.99s
#
#
# now starting generation 18 of data
#
#
# Epoch    17, Pass number 1, objective: 0.23029, exploration: 0.25, number of games played: 6985, step duration: 0.043s
# Epoch    17, Pass number 10, objective: 0.16504, exploration: 0.25, number of games played: 6985, step duration: 0.047s
# epoch duration 11.05s
#
#
# now starting generation 19 of data
#
#
# Epoch    18, Pass number 1, objective: 0.21627, exploration: 0.25, number of games played: 7368, step duration: 0.041s
# Epoch    18, Pass number 10, objective: 0.15398, exploration: 0.25, number of games played: 7368, step duration: 0.042s
# epoch duration 11.05s
#
#
# now starting generation 20 of data
#
#
# Epoch    19, Pass number 1, objective: 0.22420, exploration: 0.25, number of games played: 7730, step duration: 0.046s
# Epoch    19, Pass number 10, objective: 0.15340, exploration: 0.25, number of games played: 7730, step duration: 0.051s
# epoch duration 10.72s
#
#
# now starting generation 21 of data
#
#
# Epoch    20, Pass number 1, objective: 0.23146, exploration: 0.25, number of games played: 8126, step duration: 0.050s
# Epoch    20, Pass number 10, objective: 0.15555, exploration: 0.25, number of games played: 8126, step duration: 0.052s
# epoch duration 10.91s
#
#
# As X, neural network has a score of  69-  0- 31 vs 0-depth minimax
# As O, neural network has a score of  59-  0- 41 vs 0-depth minimax
#
# elapsed time: 246.204s
#
#
#
# now starting generation 22 of data
#
#
# Epoch    21, Pass number 1, objective: 0.23023, exploration: 0.25, number of games played: 8486, step duration: 0.048s
# Epoch    21, Pass number 10, objective: 0.16379, exploration: 0.25, number of games played: 8486, step duration: 0.051s
# epoch duration 11.15s
#
#
# now starting generation 23 of data
#
#
# Epoch    22, Pass number 1, objective: 0.24760, exploration: 0.25, number of games played: 8867, step duration: 0.050s
# Epoch    22, Pass number 10, objective: 0.17420, exploration: 0.25, number of games played: 8867, step duration: 0.061s
# epoch duration 10.87s
#
#
# now starting generation 24 of data
#
#
# Epoch    23, Pass number 1, objective: 0.20783, exploration: 0.25, number of games played: 9243, step duration: 0.047s
# Epoch    23, Pass number 10, objective: 0.14788, exploration: 0.25, number of games played: 9243, step duration: 0.052s
# epoch duration 10.99s
#
#
# now starting generation 25 of data
#
#
# Epoch    24, Pass number 1, objective: 0.23082, exploration: 0.25, number of games played: 9633, step duration: 0.042s
# Epoch    24, Pass number 10, objective: 0.16174, exploration: 0.25, number of games played: 9633, step duration: 0.042s
# epoch duration 10.82s
#
#
# now starting generation 26 of data
#
#
# Epoch    25, Pass number 1, objective: 0.22223, exploration: 0.25, number of games played: 10003, step duration: 0.042s
# Epoch    25, Pass number 10, objective: 0.15219, exploration: 0.25, number of games played: 10003, step duration: 0.042s
# epoch duration 10.69s
#
#
# now starting generation 27 of data
#
#
# Epoch    26, Pass number 1, objective: 0.23571, exploration: 0.25, number of games played: 10390, step duration: 0.059s
# Epoch    26, Pass number 10, objective: 0.15683, exploration: 0.25, number of games played: 10390, step duration: 0.047s
# epoch duration 11.02s
#
#
# now starting generation 28 of data
#
#
# Epoch    27, Pass number 1, objective: 0.24400, exploration: 0.25, number of games played: 10775, step duration: 0.052s
# Epoch    27, Pass number 10, objective: 0.16500, exploration: 0.25, number of games played: 10775, step duration: 0.055s
# epoch duration 11.26s
#
#
# now starting generation 29 of data
#
#
# Epoch    28, Pass number 1, objective: 0.22775, exploration: 0.25, number of games played: 11155, step duration: 0.060s
# Epoch    28, Pass number 10, objective: 0.15439, exploration: 0.25, number of games played: 11155, step duration: 0.061s
# epoch duration 11.15s
#
#
# now starting generation 30 of data
#
#
# Epoch    29, Pass number 1, objective: 0.22919, exploration: 0.25, number of games played: 11516, step duration: 0.041s
# Epoch    29, Pass number 10, objective: 0.16271, exploration: 0.25, number of games played: 11516, step duration: 0.043s
# epoch duration 11.01s
#
#
# now starting generation 31 of data
#
#
# Epoch    30, Pass number 1, objective: 0.23231, exploration: 0.25, number of games played: 11881, step duration: 0.060s
# Epoch    30, Pass number 10, objective: 0.17026, exploration: 0.25, number of games played: 11881, step duration: 0.062s
# epoch duration 11.00s
#
#
# As X, neural network has a score of  79-  0- 21 vs 0-depth minimax
# As O, neural network has a score of  67-  0- 33 vs 0-depth minimax
#
# elapsed time: 357.742s
#
#
#
# now starting generation 32 of data
#
#
# Epoch    31, Pass number 1, objective: 0.21161, exploration: 0.25, number of games played: 12242, step duration: 0.046s
# Epoch    31, Pass number 10, objective: 0.14875, exploration: 0.25, number of games played: 12242, step duration: 0.053s
# epoch duration 11.14s
#
#
# now starting generation 33 of data
#
#
# Epoch    32, Pass number 1, objective: 0.22259, exploration: 0.25, number of games played: 12600, step duration: 0.049s
# Epoch    32, Pass number 10, objective: 0.15852, exploration: 0.25, number of games played: 12600, step duration: 0.052s
# epoch duration 11.00s
#
#
# now starting generation 34 of data
#
#
# Epoch    33, Pass number 1, objective: 0.23186, exploration: 0.24, number of games played: 12969, step duration: 0.058s
# Epoch    33, Pass number 10, objective: 0.16634, exploration: 0.24, number of games played: 12969, step duration: 0.041s
# epoch duration 10.99s
#
#
# now starting generation 35 of data
#
#
# Epoch    34, Pass number 1, objective: 0.21984, exploration: 0.24, number of games played: 13347, step duration: 0.043s
# Epoch    34, Pass number 10, objective: 0.16139, exploration: 0.24, number of games played: 13347, step duration: 0.046s
# epoch duration 10.96s
#
#
# now starting generation 36 of data
#
#
# Epoch    35, Pass number 1, objective: 0.20389, exploration: 0.24, number of games played: 13691, step duration: 0.042s
# Epoch    35, Pass number 10, objective: 0.13315, exploration: 0.24, number of games played: 13691, step duration: 0.041s
# epoch duration 10.97s
#
#
# now starting generation 37 of data
#
#
# Epoch    36, Pass number 1, objective: 0.22062, exploration: 0.24, number of games played: 14051, step duration: 0.043s
# Epoch    36, Pass number 10, objective: 0.14327, exploration: 0.24, number of games played: 14051, step duration: 0.047s
# epoch duration 10.69s
#
#
# now starting generation 38 of data
#
#
# Epoch    37, Pass number 1, objective: 0.22076, exploration: 0.24, number of games played: 14395, step duration: 0.041s
# Epoch    37, Pass number 10, objective: 0.15571, exploration: 0.24, number of games played: 14395, step duration: 0.056s
# epoch duration 10.94s
#
#
# now starting generation 39 of data
#
#
# Epoch    38, Pass number 1, objective: 0.23539, exploration: 0.24, number of games played: 14743, step duration: 0.056s
# Epoch    38, Pass number 10, objective: 0.15977, exploration: 0.24, number of games played: 14743, step duration: 0.058s
# epoch duration 11.10s
#
#
# now starting generation 40 of data
#
#
# Epoch    39, Pass number 1, objective: 0.22760, exploration: 0.24, number of games played: 15102, step duration: 0.042s
# Epoch    39, Pass number 10, objective: 0.15779, exploration: 0.24, number of games played: 15102, step duration: 0.041s
# epoch duration 10.83s
#
#
# now starting generation 41 of data
#
#
# Epoch    40, Pass number 1, objective: 0.21442, exploration: 0.24, number of games played: 15452, step duration: 0.042s
# Epoch    40, Pass number 10, objective: 0.14805, exploration: 0.24, number of games played: 15452, step duration: 0.042s
# epoch duration 10.90s
#
#
# As X, neural network has a score of  60-  0- 40 vs 0-depth minimax
# As O, neural network has a score of  64-  0- 36 vs 0-depth minimax
#
# elapsed time: 469.142s
#
#
#
# now starting generation 42 of data
#
#
# Epoch    41, Pass number 1, objective: 0.21543, exploration: 0.24, number of games played: 15829, step duration: 0.042s
# Epoch    41, Pass number 10, objective: 0.15687, exploration: 0.24, number of games played: 15829, step duration: 0.055s
# epoch duration 10.98s
#
#
# now starting generation 43 of data
#
#
# Epoch    42, Pass number 1, objective: 0.21680, exploration: 0.24, number of games played: 16207, step duration: 0.042s
# Epoch    42, Pass number 10, objective: 0.15309, exploration: 0.24, number of games played: 16207, step duration: 0.041s
# epoch duration 11.05s
#
#
# now starting generation 44 of data
#
#
# Epoch    43, Pass number 1, objective: 0.23451, exploration: 0.24, number of games played: 16576, step duration: 0.055s
# Epoch    43, Pass number 10, objective: 0.15583, exploration: 0.24, number of games played: 16576, step duration: 0.049s
# epoch duration 11.02s
#
#
# now starting generation 45 of data
#
#
# Epoch    44, Pass number 1, objective: 0.21350, exploration: 0.24, number of games played: 16935, step duration: 0.058s
# Epoch    44, Pass number 10, objective: 0.14795, exploration: 0.24, number of games played: 16935, step duration: 0.057s
# epoch duration 11.16s
#
#
# now starting generation 46 of data
#
#
# Epoch    45, Pass number 1, objective: 0.21794, exploration: 0.24, number of games played: 17330, step duration: 0.044s
# Epoch    45, Pass number 10, objective: 0.14351, exploration: 0.24, number of games played: 17330, step duration: 0.054s
# epoch duration 11.29s
#
#
# now starting generation 47 of data
#
#
# Epoch    46, Pass number 1, objective: 0.22967, exploration: 0.24, number of games played: 17711, step duration: 0.053s
# Epoch    46, Pass number 10, objective: 0.15364, exploration: 0.24, number of games played: 17711, step duration: 0.048s
# epoch duration 11.22s
#
#
# now starting generation 48 of data
#
#
# Epoch    47, Pass number 1, objective: 0.23962, exploration: 0.24, number of games played: 18072, step duration: 0.049s
# Epoch    47, Pass number 10, objective: 0.16094, exploration: 0.24, number of games played: 18072, step duration: 0.050s
# epoch duration 11.11s
#
#
# now starting generation 49 of data
#
#
# Epoch    48, Pass number 1, objective: 0.21383, exploration: 0.24, number of games played: 18407, step duration: 0.049s
# Epoch    48, Pass number 10, objective: 0.14683, exploration: 0.24, number of games played: 18407, step duration: 0.061s
# epoch duration 11.20s
#
#
# now starting generation 50 of data
#
#
# Epoch    49, Pass number 1, objective: 0.21644, exploration: 0.24, number of games played: 18767, step duration: 0.060s
# Epoch    49, Pass number 10, objective: 0.15012, exploration: 0.24, number of games played: 18767, step duration: 0.052s
# epoch duration 11.24s
#
#
# now starting generation 51 of data
#
#
# Epoch    50, Pass number 1, objective: 0.22145, exploration: 0.24, number of games played: 19135, step duration: 0.056s
# Epoch    50, Pass number 10, objective: 0.16150, exploration: 0.24, number of games played: 19135, step duration: 0.055s
# epoch duration 11.36s
#
#
# As X, neural network has a score of  84-  0- 16 vs 0-depth minimax
# As O, neural network has a score of  76-  0- 24 vs 0-depth minimax
#
# elapsed time: 582.626s
#
#
#
# now starting generation 52 of data
#
#
# Epoch    51, Pass number 1, objective: 0.21422, exploration: 0.24, number of games played: 19512, step duration: 0.053s
# Epoch    51, Pass number 10, objective: 0.15024, exploration: 0.24, number of games played: 19512, step duration: 0.053s
# epoch duration 11.16s
#
#
# now starting generation 53 of data
#
#
# Epoch    52, Pass number 1, objective: 0.21881, exploration: 0.24, number of games played: 19885, step duration: 0.053s
# Epoch    52, Pass number 10, objective: 0.15036, exploration: 0.24, number of games played: 19885, step duration: 0.047s
# epoch duration 11.10s
#
#
# now starting generation 54 of data
#
#
# Epoch    53, Pass number 1, objective: 0.22477, exploration: 0.24, number of games played: 20228, step duration: 0.043s
# Epoch    53, Pass number 10, objective: 0.15002, exploration: 0.24, number of games played: 20228, step duration: 0.052s
# epoch duration 11.11s
#
#
# now starting generation 55 of data
#
#
# Epoch    54, Pass number 1, objective: 0.21971, exploration: 0.24, number of games played: 20587, step duration: 0.049s
# Epoch    54, Pass number 10, objective: 0.14406, exploration: 0.24, number of games played: 20587, step duration: 0.053s
# epoch duration 10.98s
#
#
# now starting generation 56 of data
#
#
# Epoch    55, Pass number 1, objective: 0.22608, exploration: 0.24, number of games played: 20949, step duration: 0.049s
# Epoch    55, Pass number 10, objective: 0.15798, exploration: 0.24, number of games played: 20949, step duration: 0.050s
# epoch duration 11.03s
#
#
# now starting generation 57 of data
#
#
# Epoch    56, Pass number 1, objective: 0.21860, exploration: 0.24, number of games played: 21311, step duration: 0.050s
# Epoch    56, Pass number 10, objective: 0.15481, exploration: 0.24, number of games played: 21311, step duration: 0.047s
# epoch duration 10.99s
#
#
# now starting generation 58 of data
#
#
# Epoch    57, Pass number 1, objective: 0.21093, exploration: 0.24, number of games played: 21661, step duration: 0.051s
# Epoch    57, Pass number 10, objective: 0.14027, exploration: 0.24, number of games played: 21661, step duration: 0.047s
# epoch duration 11.01s
#
#
# now starting generation 59 of data
#
#
# Epoch    58, Pass number 1, objective: 0.23050, exploration: 0.24, number of games played: 22055, step duration: 0.046s
# Epoch    58, Pass number 10, objective: 0.16658, exploration: 0.24, number of games played: 22055, step duration: 0.048s
# epoch duration 11.28s
#
#
# now starting generation 60 of data
#
#
# Epoch    59, Pass number 1, objective: 0.22654, exploration: 0.24, number of games played: 22447, step duration: 0.047s
# Epoch    59, Pass number 10, objective: 0.15335, exploration: 0.24, number of games played: 22447, step duration: 0.062s
# epoch duration 11.09s
#
#
# now starting generation 61 of data
#
#
# Epoch    60, Pass number 1, objective: 0.21507, exploration: 0.24, number of games played: 22832, step duration: 0.059s
# Epoch    60, Pass number 10, objective: 0.14901, exploration: 0.24, number of games played: 22832, step duration: 0.062s
# epoch duration 11.34s
#
#
# As X, neural network has a score of  62-  0- 38 vs 0-depth minimax
# As O, neural network has a score of  74-  1- 25 vs 0-depth minimax
#
# elapsed time: 695.792s
#
#
#
# now starting generation 62 of data
#
#
# Epoch    61, Pass number 1, objective: 0.23069, exploration: 0.24, number of games played: 23212, step duration: 0.055s
# Epoch    61, Pass number 10, objective: 0.16940, exploration: 0.24, number of games played: 23212, step duration: 0.041s
# epoch duration 11.19s
#
#
# now starting generation 63 of data
#
#
# Epoch    62, Pass number 1, objective: 0.22170, exploration: 0.24, number of games played: 23563, step duration: 0.050s
# Epoch    62, Pass number 10, objective: 0.15391, exploration: 0.24, number of games played: 23563, step duration: 0.056s
# epoch duration 10.95s
#
#
# now starting generation 64 of data
#
#
# Epoch    63, Pass number 1, objective: 0.23640, exploration: 0.24, number of games played: 23960, step duration: 0.042s
# Epoch    63, Pass number 10, objective: 0.16482, exploration: 0.24, number of games played: 23960, step duration: 0.053s
# epoch duration 11.11s
#
#
# now starting generation 65 of data
#
#
# Epoch    64, Pass number 1, objective: 0.21524, exploration: 0.24, number of games played: 24339, step duration: 0.041s
# Epoch    64, Pass number 10, objective: 0.14515, exploration: 0.24, number of games played: 24339, step duration: 0.064s
# epoch duration 11.28s
#
#
# now starting generation 66 of data
#
#
# Epoch    65, Pass number 1, objective: 0.21431, exploration: 0.24, number of games played: 24717, step duration: 0.043s
# Epoch    65, Pass number 10, objective: 0.14394, exploration: 0.24, number of games played: 24717, step duration: 0.052s
# epoch duration 11.29s
#
#
# now starting generation 67 of data
#
#
# Epoch    66, Pass number 1, objective: 0.23473, exploration: 0.24, number of games played: 25124, step duration: 0.063s
# Epoch    66, Pass number 10, objective: 0.15861, exploration: 0.24, number of games played: 25124, step duration: 0.064s
# epoch duration 11.66s
#
#
# now starting generation 68 of data
#
#
# Epoch    67, Pass number 1, objective: 0.23163, exploration: 0.24, number of games played: 25495, step duration: 0.049s
# Epoch    67, Pass number 10, objective: 0.16003, exploration: 0.24, number of games played: 25495, step duration: 0.051s
# epoch duration 11.02s
#
#
# now starting generation 69 of data
#
#
# Epoch    68, Pass number 1, objective: 0.23499, exploration: 0.24, number of games played: 25880, step duration: 0.052s
# Epoch    68, Pass number 10, objective: 0.15868, exploration: 0.24, number of games played: 25880, step duration: 0.051s
# epoch duration 11.21s
#
#
# now starting generation 70 of data
#
#
# Epoch    69, Pass number 1, objective: 0.22549, exploration: 0.24, number of games played: 26251, step duration: 0.050s
# Epoch    69, Pass number 10, objective: 0.14902, exploration: 0.24, number of games played: 26251, step duration: 0.054s
# epoch duration 11.19s
#
#
# now starting generation 71 of data
#
#
# Epoch    70, Pass number 1, objective: 0.21803, exploration: 0.24, number of games played: 26618, step duration: 0.046s
# Epoch    70, Pass number 10, objective: 0.14329, exploration: 0.24, number of games played: 26618, step duration: 0.049s
# epoch duration 11.11s
#
#
# As X, neural network has a score of  88-  0- 12 vs 0-depth minimax
# As O, neural network has a score of  75-  0- 25 vs 0-depth minimax
#
# elapsed time: 809.479s
#
#
#
# now starting generation 72 of data
#
#
# Epoch    71, Pass number 1, objective: 0.22804, exploration: 0.24, number of games played: 26981, step duration: 0.041s
# Epoch    71, Pass number 10, objective: 0.15902, exploration: 0.24, number of games played: 26981, step duration: 0.047s
# epoch duration 11.10s
#
#
# now starting generation 73 of data
#
#
# Epoch    72, Pass number 1, objective: 0.24448, exploration: 0.24, number of games played: 27363, step duration: 0.040s
# Epoch    72, Pass number 10, objective: 0.16044, exploration: 0.24, number of games played: 27363, step duration: 0.040s
# epoch duration 10.75s
#
#
# now starting generation 74 of data
#
#
# Epoch    73, Pass number 1, objective: 0.23266, exploration: 0.24, number of games played: 27754, step duration: 0.047s
# Epoch    73, Pass number 10, objective: 0.15984, exploration: 0.24, number of games played: 27754, step duration: 0.042s
# epoch duration 11.03s
#
#
# now starting generation 75 of data
#
#
# Epoch    74, Pass number 1, objective: 0.22724, exploration: 0.24, number of games played: 28156, step duration: 0.041s
# Epoch    74, Pass number 10, objective: 0.15361, exploration: 0.24, number of games played: 28156, step duration: 0.042s
# epoch duration 11.05s
#
#
# now starting generation 76 of data
#
#
# Epoch    75, Pass number 1, objective: 0.22491, exploration: 0.24, number of games played: 28559, step duration: 0.040s
# Epoch    75, Pass number 10, objective: 0.15182, exploration: 0.24, number of games played: 28559, step duration: 0.039s
# epoch duration 10.94s
#
#
# now starting generation 77 of data
#
#
# Epoch    76, Pass number 1, objective: 0.22647, exploration: 0.24, number of games played: 28958, step duration: 0.040s
# Epoch    76, Pass number 10, objective: 0.15461, exploration: 0.24, number of games played: 28958, step duration: 0.047s
# epoch duration 10.79s
#
#
# now starting generation 78 of data
#
#
# Epoch    77, Pass number 1, objective: 0.23334, exploration: 0.24, number of games played: 29339, step duration: 0.041s
# Epoch    77, Pass number 10, objective: 0.15634, exploration: 0.24, number of games played: 29339, step duration: 0.041s
# epoch duration 10.90s
#
#
# now starting generation 79 of data
#
#
# Epoch    78, Pass number 1, objective: 0.22287, exploration: 0.24, number of games played: 29727, step duration: 0.054s
# Epoch    78, Pass number 10, objective: 0.14929, exploration: 0.24, number of games played: 29727, step duration: 0.061s
# epoch duration 11.31s
#
#
# now starting generation 80 of data
#
#
# Epoch    79, Pass number 1, objective: 0.24058, exploration: 0.24, number of games played: 30098, step duration: 0.069s
# Epoch    79, Pass number 10, objective: 0.15509, exploration: 0.24, number of games played: 30098, step duration: 0.048s
# epoch duration 11.22s
#
#
# now starting generation 81 of data
#
#
# Epoch    80, Pass number 1, objective: 0.22358, exploration: 0.24, number of games played: 30476, step duration: 0.040s
# Epoch    80, Pass number 10, objective: 0.15321, exploration: 0.24, number of games played: 30476, step duration: 0.039s
# epoch duration 10.83s
#
#
# As X, neural network has a score of  71-  0- 29 vs 0-depth minimax
# As O, neural network has a score of  69-  0- 31 vs 0-depth minimax
#
# elapsed time: 921.187s
#
#
#
# now starting generation 82 of data
#
#
# Epoch    81, Pass number 1, objective: 0.21641, exploration: 0.24, number of games played: 30835, step duration: 0.062s
# Epoch    81, Pass number 10, objective: 0.14053, exploration: 0.24, number of games played: 30835, step duration: 0.040s
# epoch duration 11.05s
#
#
# now starting generation 83 of data
#
#
# Epoch    82, Pass number 1, objective: 0.22442, exploration: 0.24, number of games played: 31188, step duration: 0.066s
# Epoch    82, Pass number 10, objective: 0.14329, exploration: 0.24, number of games played: 31188, step duration: 0.058s
# epoch duration 11.53s
#
#
# now starting generation 84 of data
#
#
# Epoch    83, Pass number 1, objective: 0.23211, exploration: 0.24, number of games played: 31548, step duration: 0.040s
# Epoch    83, Pass number 10, objective: 0.14896, exploration: 0.24, number of games played: 31548, step duration: 0.041s
# epoch duration 11.10s
#
#
# now starting generation 85 of data
#
#
# Epoch    84, Pass number 1, objective: 0.23251, exploration: 0.24, number of games played: 31909, step duration: 0.041s
# Epoch    84, Pass number 10, objective: 0.14877, exploration: 0.24, number of games played: 31909, step duration: 0.040s
# epoch duration 10.82s
#
#
# now starting generation 86 of data
#
#
# Epoch    85, Pass number 1, objective: 0.21797, exploration: 0.24, number of games played: 32269, step duration: 0.040s
# Epoch    85, Pass number 10, objective: 0.14949, exploration: 0.24, number of games played: 32269, step duration: 0.040s
# epoch duration 10.76s
#
#
# now starting generation 87 of data
#
#
# Epoch    86, Pass number 1, objective: 0.22798, exploration: 0.24, number of games played: 32642, step duration: 0.040s
# Epoch    86, Pass number 10, objective: 0.15506, exploration: 0.24, number of games played: 32642, step duration: 0.040s
# epoch duration 11.13s
#
#
# now starting generation 88 of data
#
#
# Epoch    87, Pass number 1, objective: 0.20726, exploration: 0.24, number of games played: 33006, step duration: 0.040s
# Epoch    87, Pass number 10, objective: 0.14297, exploration: 0.24, number of games played: 33006, step duration: 0.047s
# epoch duration 11.04s
#
#
# now starting generation 89 of data
#
#
# Epoch    88, Pass number 1, objective: 0.22739, exploration: 0.24, number of games played: 33396, step duration: 0.046s
# Epoch    88, Pass number 10, objective: 0.14737, exploration: 0.24, number of games played: 33396, step duration: 0.053s
# epoch duration 11.08s
#
#
# now starting generation 90 of data
#
#
# Epoch    89, Pass number 1, objective: 0.21580, exploration: 0.24, number of games played: 33778, step duration: 0.058s
# Epoch    89, Pass number 10, objective: 0.14329, exploration: 0.24, number of games played: 33778, step duration: 0.057s
# epoch duration 11.02s
#
#
# now starting generation 91 of data
#
#
# Epoch    90, Pass number 1, objective: 0.22270, exploration: 0.24, number of games played: 34159, step duration: 0.040s
# Epoch    90, Pass number 10, objective: 0.14590, exploration: 0.24, number of games played: 34159, step duration: 0.040s
# epoch duration 10.85s
#
#
# As X, neural network has a score of  68-  0- 32 vs 0-depth minimax
# As O, neural network has a score of  68-  0- 32 vs 0-depth minimax
#
# elapsed time: 1033.422s
#
#
#
# now starting generation 92 of data
#
#
# Epoch    91, Pass number 1, objective: 0.22866, exploration: 0.24, number of games played: 34533, step duration: 0.040s
# Epoch    91, Pass number 10, objective: 0.15062, exploration: 0.24, number of games played: 34533, step duration: 0.040s
# epoch duration 10.72s
#
#
# now starting generation 93 of data
#
#
# Epoch    92, Pass number 1, objective: 0.22116, exploration: 0.24, number of games played: 34902, step duration: 0.040s
# Epoch    92, Pass number 10, objective: 0.14847, exploration: 0.24, number of games played: 34902, step duration: 0.041s
# epoch duration 10.84s
#
#
# now starting generation 94 of data
#
#
# Epoch    93, Pass number 1, objective: 0.21757, exploration: 0.24, number of games played: 35281, step duration: 0.040s
# Epoch    93, Pass number 10, objective: 0.15080, exploration: 0.24, number of games played: 35281, step duration: 0.040s
# epoch duration 10.98s
#
#
# now starting generation 95 of data
#
#
# Epoch    94, Pass number 1, objective: 0.22687, exploration: 0.24, number of games played: 35663, step duration: 0.040s
# Epoch    94, Pass number 10, objective: 0.14355, exploration: 0.24, number of games played: 35663, step duration: 0.042s
# epoch duration 10.68s
#
#
# now starting generation 96 of data
#
#
# Epoch    95, Pass number 1, objective: 0.22611, exploration: 0.24, number of games played: 36039, step duration: 0.040s
# Epoch    95, Pass number 10, objective: 0.15748, exploration: 0.24, number of games played: 36039, step duration: 0.039s
# epoch duration 10.82s
#
#
# now starting generation 97 of data
#
#
# Epoch    96, Pass number 1, objective: 0.20614, exploration: 0.24, number of games played: 36424, step duration: 0.040s
# Epoch    96, Pass number 10, objective: 0.14527, exploration: 0.24, number of games played: 36424, step duration: 0.040s
# epoch duration 10.84s
#
#
# now starting generation 98 of data
#
#
# Epoch    97, Pass number 1, objective: 0.21774, exploration: 0.24, number of games played: 36799, step duration: 0.040s
# Epoch    97, Pass number 10, objective: 0.15265, exploration: 0.24, number of games played: 36799, step duration: 0.040s
# epoch duration 10.89s
#
#
# now starting generation 99 of data
#
#
# Epoch    98, Pass number 1, objective: 0.21042, exploration: 0.24, number of games played: 37144, step duration: 0.043s
# Epoch    98, Pass number 10, objective: 0.14260, exploration: 0.24, number of games played: 37144, step duration: 0.040s
# epoch duration 10.62s
#
#
# now starting generation 100 of data
#
#
# Epoch    99, Pass number 1, objective: 0.21508, exploration: 0.24, number of games played: 37525, step duration: 0.040s
# Epoch    99, Pass number 10, objective: 0.14646, exploration: 0.24, number of games played: 37525, step duration: 0.040s
# epoch duration 10.87s
#
#
# now starting generation 101 of data
#
#
# Epoch   100, Pass number 1, objective: 0.23495, exploration: 0.24, number of games played: 37889, step duration: 0.040s
# Epoch   100, Pass number 10, objective: 0.16366, exploration: 0.24, number of games played: 37889, step duration: 0.040s
# epoch duration 10.77s
#
#
# As X, neural network has a score of  86-  0- 14 vs 0-depth minimax
# As O, neural network has a score of  72-  0- 28 vs 0-depth minimax
#
# elapsed time: 1143.081s
#
#
#
# now starting generation 102 of data
#
#
# Epoch   101, Pass number 1, objective: 0.22413, exploration: 0.24, number of games played: 38277, step duration: 0.051s
# Epoch   101, Pass number 10, objective: 0.14945, exploration: 0.24, number of games played: 38277, step duration: 0.039s
# epoch duration 10.91s
#
#
# now starting generation 103 of data
#
#
# Epoch   102, Pass number 1, objective: 0.22919, exploration: 0.24, number of games played: 38652, step duration: 0.062s
# Epoch   102, Pass number 10, objective: 0.15653, exploration: 0.24, number of games played: 38652, step duration: 0.062s
# epoch duration 10.84s
#
#
# now starting generation 104 of data
#
#
# Epoch   103, Pass number 1, objective: 0.21874, exploration: 0.24, number of games played: 39037, step duration: 0.040s
# Epoch   103, Pass number 10, objective: 0.14253, exploration: 0.24, number of games played: 39037, step duration: 0.047s
# epoch duration 10.86s
#
#
# now starting generation 105 of data
#
#
# Epoch   104, Pass number 1, objective: 0.23488, exploration: 0.24, number of games played: 39415, step duration: 0.045s
# Epoch   104, Pass number 10, objective: 0.16024, exploration: 0.24, number of games played: 39415, step duration: 0.040s
# epoch duration 10.89s
#
#
# now starting generation 106 of data
#
#
# Epoch   105, Pass number 1, objective: 0.21470, exploration: 0.23, number of games played: 39782, step duration: 0.040s
# Epoch   105, Pass number 10, objective: 0.14042, exploration: 0.23, number of games played: 39782, step duration: 0.040s
# epoch duration 10.86s
#
#
# now starting generation 107 of data
#
#
# Epoch   106, Pass number 1, objective: 0.23022, exploration: 0.23, number of games played: 40158, step duration: 0.043s
# Epoch   106, Pass number 10, objective: 0.14959, exploration: 0.23, number of games played: 40158, step duration: 0.040s
# epoch duration 10.92s
#
#
# now starting generation 108 of data
#
#
# Epoch   107, Pass number 1, objective: 0.21076, exploration: 0.23, number of games played: 40540, step duration: 0.040s
# Epoch   107, Pass number 10, objective: 0.13856, exploration: 0.23, number of games played: 40540, step duration: 0.039s
# epoch duration 10.80s
#
#
# now starting generation 109 of data
#
#
# Epoch   108, Pass number 1, objective: 0.22653, exploration: 0.23, number of games played: 40927, step duration: 0.041s
# Epoch   108, Pass number 10, objective: 0.15069, exploration: 0.23, number of games played: 40927, step duration: 0.040s
# epoch duration 10.95s
#
#
# now starting generation 110 of data
#
#
# Epoch   109, Pass number 1, objective: 0.23244, exploration: 0.23, number of games played: 41295, step duration: 0.041s
# Epoch   109, Pass number 10, objective: 0.15876, exploration: 0.23, number of games played: 41295, step duration: 0.040s
# epoch duration 10.86s
#
#
# now starting generation 111 of data
#
#
# Epoch   110, Pass number 1, objective: 0.23104, exploration: 0.23, number of games played: 41705, step duration: 0.042s
# Epoch   110, Pass number 10, objective: 0.15732, exploration: 0.23, number of games played: 41705, step duration: 0.040s
# epoch duration 10.84s
#
#
# As X, neural network has a score of  83-  0- 17 vs 0-depth minimax
# As O, neural network has a score of  71-  0- 29 vs 0-depth minimax
#
# elapsed time: 1253.331s
#
#
#
# now starting generation 112 of data
#
#
# Epoch   111, Pass number 1, objective: 0.22834, exploration: 0.23, number of games played: 42086, step duration: 0.040s
# Epoch   111, Pass number 10, objective: 0.16206, exploration: 0.23, number of games played: 42086, step duration: 0.040s
# epoch duration 10.94s
#
#
# now starting generation 113 of data
#
#
# Epoch   112, Pass number 1, objective: 0.21977, exploration: 0.23, number of games played: 42468, step duration: 0.040s
# Epoch   112, Pass number 10, objective: 0.14813, exploration: 0.23, number of games played: 42468, step duration: 0.040s
# epoch duration 10.77s
#
#
# now starting generation 114 of data
#
#
# Epoch   113, Pass number 1, objective: 0.22963, exploration: 0.23, number of games played: 42847, step duration: 0.041s
# Epoch   113, Pass number 10, objective: 0.16257, exploration: 0.23, number of games played: 42847, step duration: 0.040s
# epoch duration 11.01s
#
#
# now starting generation 115 of data
#
#
# Epoch   114, Pass number 1, objective: 0.22275, exploration: 0.23, number of games played: 43204, step duration: 0.039s
# Epoch   114, Pass number 10, objective: 0.15475, exploration: 0.23, number of games played: 43204, step duration: 0.039s
# epoch duration 10.90s
#
#
# now starting generation 116 of data
#
#
# Epoch   115, Pass number 1, objective: 0.21546, exploration: 0.23, number of games played: 43600, step duration: 0.041s
# Epoch   115, Pass number 10, objective: 0.14933, exploration: 0.23, number of games played: 43600, step duration: 0.040s
# epoch duration 11.07s
#
#
# now starting generation 117 of data
#
#
# Epoch   116, Pass number 1, objective: 0.22242, exploration: 0.23, number of games played: 43970, step duration: 0.043s
# Epoch   116, Pass number 10, objective: 0.14632, exploration: 0.23, number of games played: 43970, step duration: 0.039s
# epoch duration 10.80s
#
#
# now starting generation 118 of data
#
#
# Epoch   117, Pass number 1, objective: 0.21484, exploration: 0.23, number of games played: 44336, step duration: 0.043s
# Epoch   117, Pass number 10, objective: 0.14315, exploration: 0.23, number of games played: 44336, step duration: 0.040s
# epoch duration 11.00s
#
#
# now starting generation 119 of data
#
#
# Epoch   118, Pass number 1, objective: 0.21936, exploration: 0.23, number of games played: 44719, step duration: 0.040s
# Epoch   118, Pass number 10, objective: 0.14499, exploration: 0.23, number of games played: 44719, step duration: 0.047s
# epoch duration 11.11s
#
#
# now starting generation 120 of data
#
#
# Epoch   119, Pass number 1, objective: 0.23046, exploration: 0.23, number of games played: 45093, step duration: 0.040s
# Epoch   119, Pass number 10, objective: 0.14710, exploration: 0.23, number of games played: 45093, step duration: 0.039s
# epoch duration 10.87s
#
#
# now starting generation 121 of data
#
#
# Epoch   120, Pass number 1, objective: 0.22447, exploration: 0.23, number of games played: 45468, step duration: 0.040s
# Epoch   120, Pass number 10, objective: 0.14148, exploration: 0.23, number of games played: 45468, step duration: 0.040s
# epoch duration 10.85s
#
#
# As X, neural network has a score of  85-  0- 15 vs 0-depth minimax
# As O, neural network has a score of  81-  0- 19 vs 0-depth minimax
#
# elapsed time: 1364.229s
#
#
#
# now starting generation 122 of data
#
#
# Epoch   121, Pass number 1, objective: 0.23077, exploration: 0.23, number of games played: 45842, step duration: 0.041s
# Epoch   121, Pass number 10, objective: 0.15295, exploration: 0.23, number of games played: 45842, step duration: 0.039s
# epoch duration 10.96s
#
#
# now starting generation 123 of data
#
#
# Epoch   122, Pass number 1, objective: 0.23015, exploration: 0.23, number of games played: 46205, step duration: 0.040s
# Epoch   122, Pass number 10, objective: 0.14888, exploration: 0.23, number of games played: 46205, step duration: 0.042s
# epoch duration 10.93s
#
#
# now starting generation 124 of data
#
#
# Epoch   123, Pass number 1, objective: 0.22615, exploration: 0.23, number of games played: 46581, step duration: 0.040s
# Epoch   123, Pass number 10, objective: 0.16188, exploration: 0.23, number of games played: 46581, step duration: 0.040s
# epoch duration 10.86s
#
#
# now starting generation 125 of data
#
#
# Epoch   124, Pass number 1, objective: 0.22237, exploration: 0.23, number of games played: 46962, step duration: 0.040s
# Epoch   124, Pass number 10, objective: 0.15496, exploration: 0.23, number of games played: 46962, step duration: 0.039s
# epoch duration 10.89s
#
#
# now starting generation 126 of data
#
#
# Epoch   125, Pass number 1, objective: 0.21791, exploration: 0.23, number of games played: 47322, step duration: 0.040s
# Epoch   125, Pass number 10, objective: 0.15115, exploration: 0.23, number of games played: 47322, step duration: 0.040s
# epoch duration 10.78s
#
#
# now starting generation 127 of data
#
#
# Epoch   126, Pass number 1, objective: 0.21885, exploration: 0.23, number of games played: 47683, step duration: 0.040s
# Epoch   126, Pass number 10, objective: 0.13896, exploration: 0.23, number of games played: 47683, step duration: 0.040s
# epoch duration 10.80s
#
#
# now starting generation 128 of data
#
#
# Epoch   127, Pass number 1, objective: 0.22728, exploration: 0.23, number of games played: 48049, step duration: 0.041s
# Epoch   127, Pass number 10, objective: 0.15086, exploration: 0.23, number of games played: 48049, step duration: 0.039s
# epoch duration 10.77s
#
#
# now starting generation 129 of data
#
#
# Epoch   128, Pass number 1, objective: 0.23563, exploration: 0.23, number of games played: 48417, step duration: 0.040s
# Epoch   128, Pass number 10, objective: 0.15938, exploration: 0.23, number of games played: 48417, step duration: 0.039s
# epoch duration 11.02s
#
#
# now starting generation 130 of data
#
#
# Epoch   129, Pass number 1, objective: 0.22829, exploration: 0.23, number of games played: 48796, step duration: 0.040s
# Epoch   129, Pass number 10, objective: 0.15130, exploration: 0.23, number of games played: 48796, step duration: 0.040s
# epoch duration 10.83s
#
#
# now starting generation 131 of data
#
#
# Epoch   130, Pass number 1, objective: 0.22619, exploration: 0.23, number of games played: 49180, step duration: 0.041s
# Epoch   130, Pass number 10, objective: 0.15261, exploration: 0.23, number of games played: 49180, step duration: 0.045s
# epoch duration 10.96s
#
#
# As X, neural network has a score of  60-  0- 40 vs 0-depth minimax
# As O, neural network has a score of  70-  0- 30 vs 0-depth minimax
#
# elapsed time: 1474.906s
#
#
#
# now starting generation 132 of data
#
#
# Epoch   131, Pass number 1, objective: 0.23339, exploration: 0.23, number of games played: 49563, step duration: 0.040s
# Epoch   131, Pass number 10, objective: 0.15495, exploration: 0.23, number of games played: 49563, step duration: 0.039s
# epoch duration 10.81s
#
#
# now starting generation 133 of data
#
#
# Epoch   132, Pass number 1, objective: 0.23352, exploration: 0.23, number of games played: 49946, step duration: 0.067s
# Epoch   132, Pass number 10, objective: 0.16006, exploration: 0.23, number of games played: 49946, step duration: 0.058s
# epoch duration 12.15s
#
#
# now starting generation 134 of data
#
#
# Epoch   133, Pass number 1, objective: 0.19516, exploration: 0.23, number of games played: 50319, step duration: 0.059s
# Epoch   133, Pass number 10, objective: 0.12767, exploration: 0.23, number of games played: 50319, step duration: 0.053s
# epoch duration 11.31s
#
#
# now starting generation 135 of data
#
#
# Epoch   134, Pass number 1, objective: 0.22268, exploration: 0.23, number of games played: 50687, step duration: 0.049s
# Epoch   134, Pass number 10, objective: 0.15037, exploration: 0.23, number of games played: 50687, step duration: 0.054s
# epoch duration 11.19s
#
#
# now starting generation 136 of data
#
#
# Epoch   135, Pass number 1, objective: 0.22105, exploration: 0.23, number of games played: 51058, step duration: 0.045s
# Epoch   135, Pass number 10, objective: 0.14587, exploration: 0.23, number of games played: 51058, step duration: 0.040s
# epoch duration 11.26s
#
#
# now starting generation 137 of data
#
#
# Epoch   136, Pass number 1, objective: 0.22744, exploration: 0.23, number of games played: 51458, step duration: 0.044s
# Epoch   136, Pass number 10, objective: 0.15010, exploration: 0.23, number of games played: 51458, step duration: 0.059s
# epoch duration 11.05s
#
#
# now starting generation 138 of data
#
#
# Epoch   137, Pass number 1, objective: 0.24428, exploration: 0.23, number of games played: 51872, step duration: 0.057s
# Epoch   137, Pass number 10, objective: 0.16099, exploration: 0.23, number of games played: 51872, step duration: 0.045s
# epoch duration 10.97s
#
#
# now starting generation 139 of data
#
#
# Epoch   138, Pass number 1, objective: 0.22072, exploration: 0.23, number of games played: 52230, step duration: 0.046s
# Epoch   138, Pass number 10, objective: 0.15262, exploration: 0.23, number of games played: 52230, step duration: 0.045s
# epoch duration 10.95s
#
#
# now starting generation 140 of data
#
#
# Epoch   139, Pass number 1, objective: 0.21151, exploration: 0.23, number of games played: 52587, step duration: 0.046s
# Epoch   139, Pass number 10, objective: 0.14561, exploration: 0.23, number of games played: 52587, step duration: 0.049s
# epoch duration 11.03s
#
#
# now starting generation 141 of data
#
#
# Epoch   140, Pass number 1, objective: 0.23655, exploration: 0.23, number of games played: 52974, step duration: 0.041s
# Epoch   140, Pass number 10, objective: 0.15338, exploration: 0.23, number of games played: 52974, step duration: 0.041s
# epoch duration 11.07s
#
#
# As X, neural network has a score of  78-  0- 22 vs 0-depth minimax
# As O, neural network has a score of  72-  0- 28 vs 0-depth minimax
#
# elapsed time: 1588.652s
#
#
#
# now starting generation 142 of data
#
#
# Epoch   141, Pass number 1, objective: 0.23465, exploration: 0.23, number of games played: 53367, step duration: 0.041s
# Epoch   141, Pass number 10, objective: 0.16116, exploration: 0.23, number of games played: 53367, step duration: 0.039s
# epoch duration 11.01s
#
#
# now starting generation 143 of data
#
#
# Epoch   142, Pass number 1, objective: 0.23197, exploration: 0.23, number of games played: 53777, step duration: 0.042s
# Epoch   142, Pass number 10, objective: 0.15834, exploration: 0.23, number of games played: 53777, step duration: 0.042s
# epoch duration 11.07s
#
#
# now starting generation 144 of data
#
#
# Epoch   143, Pass number 1, objective: 0.22944, exploration: 0.23, number of games played: 54165, step duration: 0.049s
# Epoch   143, Pass number 10, objective: 0.14822, exploration: 0.23, number of games played: 54165, step duration: 0.041s
# epoch duration 11.23s
#
#
# now starting generation 145 of data
#
#
# Epoch   144, Pass number 1, objective: 0.23117, exploration: 0.23, number of games played: 54569, step duration: 0.058s
# Epoch   144, Pass number 10, objective: 0.15622, exploration: 0.23, number of games played: 54569, step duration: 0.040s
# epoch duration 11.20s
#
#
# now starting generation 146 of data
#
#
# Epoch   145, Pass number 1, objective: 0.21933, exploration: 0.23, number of games played: 54956, step duration: 0.042s
# Epoch   145, Pass number 10, objective: 0.14694, exploration: 0.23, number of games played: 54956, step duration: 0.052s
# epoch duration 11.12s
#
#
# now starting generation 147 of data
#
#
# Epoch   146, Pass number 1, objective: 0.23335, exploration: 0.23, number of games played: 55339, step duration: 0.052s
# Epoch   146, Pass number 10, objective: 0.15423, exploration: 0.23, number of games played: 55339, step duration: 0.041s
# epoch duration 11.26s
#
#
# now starting generation 148 of data
#
#
# Epoch   147, Pass number 1, objective: 0.22835, exploration: 0.23, number of games played: 55712, step duration: 0.052s
# Epoch   147, Pass number 10, objective: 0.16129, exploration: 0.23, number of games played: 55712, step duration: 0.058s
# epoch duration 11.06s
#
#
# now starting generation 149 of data
#
#
# Epoch   148, Pass number 1, objective: 0.22272, exploration: 0.23, number of games played: 56078, step duration: 0.046s
# Epoch   148, Pass number 10, objective: 0.14668, exploration: 0.23, number of games played: 56078, step duration: 0.041s
# epoch duration 10.88s
#
#
# now starting generation 150 of data
#
#
# Epoch   149, Pass number 1, objective: 0.21762, exploration: 0.23, number of games played: 56451, step duration: 0.048s
# Epoch   149, Pass number 10, objective: 0.14064, exploration: 0.23, number of games played: 56451, step duration: 0.059s
# epoch duration 11.05s
#
#
# now starting generation 151 of data
#
#
# ...
# epoch duration 11.93s
#
#
# now starting generation 1079 of data
#
#
# Epoch  1078, Pass number 1, objective: 0.21596, exploration: 0.15, number of games played: 397736, step duration: 0.053s
# Epoch  1078, Pass number 10, objective: 0.12592, exploration: 0.15, number of games played: 397736, step duration: 0.041s
# epoch duration 11.73s
#
#
# now starting generation 1080 of data
#
#
# Epoch  1079, Pass number 1, objective: 0.21486, exploration: 0.15, number of games played: 398097, step duration: 0.041s
# Epoch  1079, Pass number 10, objective: 0.13271, exploration: 0.15, number of games played: 398097, step duration: 0.064s
# epoch duration 11.73s
#
#
# now starting generation 1081 of data
#
#
# Epoch  1080, Pass number 1, objective: 0.21753, exploration: 0.15, number of games played: 398454, step duration: 0.041s
# Epoch  1080, Pass number 10, objective: 0.12995, exploration: 0.15, number of games played: 398454, step duration: 0.049s
# epoch duration 11.76s
#
#
# As X, neural network has a score of  81-  0- 19 vs 0-depth minimax
# As O, neural network has a score of  70-  0- 30 vs 0-depth minimax
#
# elapsed time: 12489.385s
#
#
#
# now starting generation 1082 of data
#
#
# Epoch  1081, Pass number 1, objective: 0.21381, exploration: 0.15, number of games played: 398821, step duration: 0.054s
# Epoch  1081, Pass number 10, objective: 0.12179, exploration: 0.15, number of games played: 398821, step duration: 0.060s
# epoch duration 11.78s
#
#
# now starting generation 1083 of data
#
#
# Epoch  1082, Pass number 1, objective: 0.22227, exploration: 0.15, number of games played: 399192, step duration: 0.041s
# Epoch  1082, Pass number 10, objective: 0.13428, exploration: 0.15, number of games played: 399192, step duration: 0.055s
# epoch duration 11.66s
#
#
# now starting generation 1084 of data
#
#
# Epoch  1083, Pass number 1, objective: 0.24200, exploration: 0.15, number of games played: 399555, step duration: 0.041s
# Epoch  1083, Pass number 10, objective: 0.13950, exploration: 0.15, number of games played: 399555, step duration: 0.046s
# epoch duration 11.73s
#
#
# now starting generation 1085 of data
#
#
# Epoch  1084, Pass number 1, objective: 0.21371, exploration: 0.15, number of games played: 399924, step duration: 0.040s
# Epoch  1084, Pass number 10, objective: 0.13331, exploration: 0.15, number of games played: 399924, step duration: 0.045s
# epoch duration 11.78s
#
#
# now starting generation 1086 of data
#
#
# Epoch  1085, Pass number 1, objective: 0.21547, exploration: 0.15, number of games played: 400308, step duration: 0.041s
# Epoch  1085, Pass number 10, objective: 0.13481, exploration: 0.15, number of games played: 400308, step duration: 0.042s
# epoch duration 11.83s
#
#
# now starting generation 1087 of data
#
#
# Epoch  1086, Pass number 1, objective: 0.21707, exploration: 0.15, number of games played: 400672, step duration: 0.048s
# Epoch  1086, Pass number 10, objective: 0.13932, exploration: 0.15, number of games played: 400672, step duration: 0.041s
# epoch duration 11.84s
#
#
# now starting generation 1088 of data
#
#
# Epoch  1087, Pass number 1, objective: 0.21135, exploration: 0.15, number of games played: 401048, step duration: 0.041s
# Epoch  1087, Pass number 10, objective: 0.12570, exploration: 0.15, number of games played: 401048, step duration: 0.063s
# epoch duration 12.08s
#
#
# now starting generation 1089 of data
#
#
# Epoch  1088, Pass number 1, objective: 0.20364, exploration: 0.15, number of games played: 401392, step duration: 0.041s
# Epoch  1088, Pass number 10, objective: 0.11730, exploration: 0.15, number of games played: 401392, step duration: 0.054s
# epoch duration 11.76s
#
#
# now starting generation 1090 of data
#
#
# Epoch  1089, Pass number 1, objective: 0.21143, exploration: 0.15, number of games played: 401762, step duration: 0.054s
# Epoch  1089, Pass number 10, objective: 0.12494, exploration: 0.15, number of games played: 401762, step duration: 0.041s
# epoch duration 12.15s
#
#
# now starting generation 1091 of data
#
#
# Epoch  1090, Pass number 1, objective: 0.21025, exploration: 0.15, number of games played: 402112, step duration: 0.040s
# Epoch  1090, Pass number 10, objective: 0.12790, exploration: 0.15, number of games played: 402112, step duration: 0.042s
# epoch duration 11.97s
#
#
# As X, neural network has a score of  70-  0- 30 vs 0-depth minimax
# As O, neural network has a score of  71-  0- 29 vs 0-depth minimax
#
# elapsed time: 12610.112s
#
#
#
# now starting generation 1092 of data
#
#
# Epoch  1091, Pass number 1, objective: 0.20430, exploration: 0.15, number of games played: 402480, step duration: 0.042s
# Epoch  1091, Pass number 10, objective: 0.12444, exploration: 0.15, number of games played: 402480, step duration: 0.042s
# epoch duration 11.77s
#
#
# now starting generation 1093 of data
#
#
# Epoch  1092, Pass number 1, objective: 0.19887, exploration: 0.15, number of games played: 402851, step duration: 0.041s
# Epoch  1092, Pass number 10, objective: 0.11738, exploration: 0.15, number of games played: 402851, step duration: 0.042s
# epoch duration 11.64s
#
#
# now starting generation 1094 of data
#
#
# Epoch  1093, Pass number 1, objective: 0.21358, exploration: 0.15, number of games played: 403213, step duration: 0.043s
# Epoch  1093, Pass number 10, objective: 0.13057, exploration: 0.15, number of games played: 403213, step duration: 0.057s
# epoch duration 11.83s
#
#
# now starting generation 1095 of data
#
#
# Epoch  1094, Pass number 1, objective: 0.22005, exploration: 0.15, number of games played: 403580, step duration: 0.041s
# Epoch  1094, Pass number 10, objective: 0.12317, exploration: 0.15, number of games played: 403580, step duration: 0.054s
# epoch duration 11.92s
#
#
# now starting generation 1096 of data
#
#
# Epoch  1095, Pass number 1, objective: 0.21919, exploration: 0.15, number of games played: 403981, step duration: 0.051s
# Epoch  1095, Pass number 10, objective: 0.13313, exploration: 0.15, number of games played: 403981, step duration: 0.046s
# epoch duration 11.82s
#
#
# now starting generation 1097 of data
#
#
# Epoch  1096, Pass number 1, objective: 0.23177, exploration: 0.15, number of games played: 404384, step duration: 0.044s
# Epoch  1096, Pass number 10, objective: 0.15192, exploration: 0.15, number of games played: 404384, step duration: 0.058s
# epoch duration 11.82s
#
#
# now starting generation 1098 of data
#
#
# Epoch  1097, Pass number 1, objective: 0.20644, exploration: 0.15, number of games played: 404723, step duration: 0.040s
# Epoch  1097, Pass number 10, objective: 0.13244, exploration: 0.15, number of games played: 404723, step duration: 0.060s
# epoch duration 11.79s
#
#
# now starting generation 1099 of data
#
#
# Epoch  1098, Pass number 1, objective: 0.21565, exploration: 0.15, number of games played: 405081, step duration: 0.041s
# Epoch  1098, Pass number 10, objective: 0.13017, exploration: 0.15, number of games played: 405081, step duration: 0.042s
# epoch duration 11.89s
#
#
# now starting generation 1100 of data
#
#
# Epoch  1099, Pass number 1, objective: 0.20020, exploration: 0.15, number of games played: 405440, step duration: 0.041s
# Epoch  1099, Pass number 10, objective: 0.12354, exploration: 0.15, number of games played: 405440, step duration: 0.051s
# epoch duration 11.74s
#
#
# now starting generation 1101 of data
#
#
# Epoch  1100, Pass number 1, objective: 0.21189, exploration: 0.15, number of games played: 405792, step duration: 0.042s
# Epoch  1100, Pass number 10, objective: 0.12214, exploration: 0.15, number of games played: 405792, step duration: 0.058s
# epoch duration 11.79s
#
#
# As X, neural network has a score of  88-  0- 12 vs 0-depth minimax
# As O, neural network has a score of  85-  0- 15 vs 0-depth minimax
#
# elapsed time: 12729.720s
#
#
#
# now starting generation 1102 of data
#
#
# Epoch  1101, Pass number 1, objective: 0.22103, exploration: 0.15, number of games played: 406150, step duration: 0.042s
# Epoch  1101, Pass number 10, objective: 0.12475, exploration: 0.15, number of games played: 406150, step duration: 0.061s
# epoch duration 11.64s
#
#
# now starting generation 1103 of data
#
#
# Epoch  1102, Pass number 1, objective: 0.20661, exploration: 0.15, number of games played: 406511, step duration: 0.041s
# Epoch  1102, Pass number 10, objective: 0.13002, exploration: 0.15, number of games played: 406511, step duration: 0.048s
# epoch duration 11.80s
#
#
# now starting generation 1104 of data
#
#
# Epoch  1103, Pass number 1, objective: 0.20172, exploration: 0.15, number of games played: 406904, step duration: 0.041s
# Epoch  1103, Pass number 10, objective: 0.12298, exploration: 0.15, number of games played: 406904, step duration: 0.055s
# epoch duration 12.04s
#
#
# now starting generation 1105 of data
#
#
# Epoch  1104, Pass number 1, objective: 0.21101, exploration: 0.15, number of games played: 407277, step duration: 0.041s
# Epoch  1104, Pass number 10, objective: 0.12849, exploration: 0.15, number of games played: 407277, step duration: 0.046s
# epoch duration 11.75s
#
#
# now starting generation 1106 of data
#
#
# Epoch  1105, Pass number 1, objective: 0.23280, exploration: 0.15, number of games played: 407646, step duration: 0.041s
# Epoch  1105, Pass number 10, objective: 0.13365, exploration: 0.15, number of games played: 407646, step duration: 0.059s
# epoch duration 11.94s
#
#
# now starting generation 1107 of data
#
#
# Epoch  1106, Pass number 1, objective: 0.22812, exploration: 0.15, number of games played: 408027, step duration: 0.060s
# Epoch  1106, Pass number 10, objective: 0.13737, exploration: 0.15, number of games played: 408027, step duration: 0.050s
# epoch duration 11.88s
#
#
# now starting generation 1108 of data
#
#
# Epoch  1107, Pass number 1, objective: 0.22063, exploration: 0.15, number of games played: 408432, step duration: 0.041s
# Epoch  1107, Pass number 10, objective: 0.14026, exploration: 0.15, number of games played: 408432, step duration: 0.067s
# epoch duration 11.81s
#
#
# now starting generation 1109 of data
#
#
# Epoch  1108, Pass number 1, objective: 0.23518, exploration: 0.15, number of games played: 408809, step duration: 0.041s
# Epoch  1108, Pass number 10, objective: 0.13939, exploration: 0.15, number of games played: 408809, step duration: 0.053s
# epoch duration 11.76s
#
#
# now starting generation 1110 of data
#
#
# Epoch  1109, Pass number 1, objective: 0.23001, exploration: 0.15, number of games played: 409222, step duration: 0.041s
# Epoch  1109, Pass number 10, objective: 0.14294, exploration: 0.15, number of games played: 409222, step duration: 0.062s
# epoch duration 11.72s
#
#
# now starting generation 1111 of data
#
#
# Epoch  1110, Pass number 1, objective: 0.24917, exploration: 0.15, number of games played: 409608, step duration: 0.053s
# Epoch  1110, Pass number 10, objective: 0.14732, exploration: 0.15, number of games played: 409608, step duration: 0.048s
# epoch duration 12.30s
#
#
# As X, neural network has a score of  75-  0- 25 vs 0-depth minimax
# As O, neural network has a score of  71-  0- 29 vs 0-depth minimax
#
# elapsed time: 12850.132s
#
#
#
# now starting generation 1112 of data
#
#
# Epoch  1111, Pass number 1, objective: 0.22451, exploration: 0.15, number of games played: 409989, step duration: 0.041s
# Epoch  1111, Pass number 10, objective: 0.14961, exploration: 0.15, number of games played: 409989, step duration: 0.045s
# epoch duration 11.86s
#
#
# now starting generation 1113 of data
#
#
# Epoch  1112, Pass number 1, objective: 0.21123, exploration: 0.15, number of games played: 410358, step duration: 0.040s
# Epoch  1112, Pass number 10, objective: 0.13777, exploration: 0.15, number of games played: 410358, step duration: 0.062s
# epoch duration 11.82s
#
#
# now starting generation 1114 of data
#
#
# Epoch  1113, Pass number 1, objective: 0.23282, exploration: 0.15, number of games played: 410732, step duration: 0.041s
# Epoch  1113, Pass number 10, objective: 0.14171, exploration: 0.15, number of games played: 410732, step duration: 0.056s
# epoch duration 12.01s
#
#
# now starting generation 1115 of data
#
#
# Epoch  1114, Pass number 1, objective: 0.22290, exploration: 0.15, number of games played: 411085, step duration: 0.042s
# Epoch  1114, Pass number 10, objective: 0.13223, exploration: 0.15, number of games played: 411085, step duration: 0.057s
# epoch duration 12.31s
#
#
# now starting generation 1116 of data
#
#
# Epoch  1115, Pass number 1, objective: 0.22601, exploration: 0.15, number of games played: 411434, step duration: 0.041s
# Epoch  1115, Pass number 10, objective: 0.13965, exploration: 0.15, number of games played: 411434, step duration: 0.054s
# epoch duration 12.14s
#
#
# now starting generation 1117 of data
#
#
# Epoch  1116, Pass number 1, objective: 0.21812, exploration: 0.15, number of games played: 411809, step duration: 0.041s
# Epoch  1116, Pass number 10, objective: 0.13914, exploration: 0.15, number of games played: 411809, step duration: 0.047s
# epoch duration 12.40s
#
#
# now starting generation 1118 of data
#
#
# Epoch  1117, Pass number 1, objective: 0.22464, exploration: 0.15, number of games played: 412181, step duration: 0.046s
# Epoch  1117, Pass number 10, objective: 0.13861, exploration: 0.15, number of games played: 412181, step duration: 0.072s
# epoch duration 12.23s
#
#
# now starting generation 1119 of data
#
#
# Epoch  1118, Pass number 1, objective: 0.23338, exploration: 0.15, number of games played: 412530, step duration: 0.044s
# Epoch  1118, Pass number 10, objective: 0.13839, exploration: 0.15, number of games played: 412530, step duration: 0.049s
# epoch duration 11.99s
#
#
# now starting generation 1120 of data
#
#
# Epoch  1119, Pass number 1, objective: 0.22016, exploration: 0.15, number of games played: 412898, step duration: 0.051s
# Epoch  1119, Pass number 10, objective: 0.13409, exploration: 0.15, number of games played: 412898, step duration: 0.068s
# epoch duration 12.27s
#
#
# now starting generation 1121 of data
#
#
# Epoch  1120, Pass number 1, objective: 0.20273, exploration: 0.15, number of games played: 413247, step duration: 0.041s
# Epoch  1120, Pass number 10, objective: 0.12851, exploration: 0.15, number of games played: 413247, step duration: 0.052s
# epoch duration 12.06s
#
#
# As X, neural network has a score of  91-  0-  9 vs 0-depth minimax
# As O, neural network has a score of  80-  0- 20 vs 0-depth minimax
#
# elapsed time: 12972.792s
#
#
#
# now starting generation 1122 of data
#
#
# Epoch  1121, Pass number 1, objective: 0.21233, exploration: 0.15, number of games played: 413619, step duration: 0.046s
# Epoch  1121, Pass number 10, objective: 0.12887, exploration: 0.15, number of games played: 413619, step duration: 0.055s
# epoch duration 11.83s
#
#
# now starting generation 1123 of data
#
#
# Epoch  1122, Pass number 1, objective: 0.21549, exploration: 0.15, number of games played: 413975, step duration: 0.041s
# Epoch  1122, Pass number 10, objective: 0.13295, exploration: 0.15, number of games played: 413975, step duration: 0.067s
# epoch duration 12.00s
#
#
# now starting generation 1124 of data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-c15a4a7691a4> in <module>()
#      79         value_history = []
#      80         while not game_over(np.copy(current_state)):
# ---> 81             current_value , next_state = play_one_move(current_state,value_fun,exploration)
#      82             board_history.append(current_state)
#      83             value_history.append(current_value)
#
# <ipython-input-3-80e2580352b7> in play_one_move(future_board, value_fun, exploration)
#     118             dummy_board[np.where(dummy_board[:,move]==0)[0][-1],move] = 1
#     119             # dummy_board = dummy_board.reshape(1,42)
# --> 120             if cccc.winner(dummy_board):
#     121                 move_values[move] = cccc.winner(dummy_board)
#     122             else:
#
# C:\Users\Todd\Dropbox\Data Incubator Challenge April\deep_learning\Deep-Learning\Deep-Learning\connect_four.pyc in winner(board)
#      31     result = 0
#      32     for item in possible_wins:
# ---> 33         if len(set(item)) == 1 and item[0] != 0:
#      34             result = item[0]
#      35             break
#
# KeyboardInterrupt:

# %%
# save the chromes
# np.savez('TD_cccc_100_nn',lasagne.layers.get_all_param_values(value_out))

# %%
validation_str = 2
player_1 = alpha_beta(2)
player_2 = alpha_beta(0)
print ' '
print ' '
test_result = {'wins':0,'ties':0,'losses':0}
for j in range(100):
    result = cccc.play(player_1,player_2)
    if result.winner ==1:
        test_result['wins'] +=1
    if result.winner == 0:
        test_result['ties'] +=1
    if result.winner == -1:
        test_result['losses'] +=1


print 'As X, neural network has a score of {:3d}-{:3d}-{:3d} vs {}-depth minimax'.format(test_result['wins'],
                                                       test_result['ties'],test_result['losses'],validation_str)

test_result = {'wins':0,'ties':0,'losses':0}

for j in range(100):
    result = cccc.play(player_2,player_1)
    if result.winner ==1:
        test_result['losses'] +=1
    if result.winner == 0:
        test_result['ties'] +=1
    if result.winner == -1:
        test_result['wins'] +=1

print 'As O, neural network has a score of {:3d}-{:3d}-{:3d} vs {}-depth minimax'.format(test_result['wins'],
                                                    test_result['ties'],test_result['losses'],validation_str)
print ' '
print 'elapsed time: {:3.3f}s'.format(time.clock()-t0)
print ' '
# Out:
#
#
# As X, neural network has a score of  99-  0-  1 vs 2-depth minimax
# As O, neural network has a score of  95-  0-  5 vs 2-depth minimax
#
# elapsed time: 5269.413s

# %%
cccc.play(cccc.player(),alpha_beta(8))
# Out:
# it is X's turn, please choose a move
#
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 4
# it is X's turn, please choose a move
#
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   | X |   |   | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 2
# it is X's turn, please choose a move
#
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      | X |   | X | O |   | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 4
# it is X's turn, please choose a move
#
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      | O |   | X |   |   |
#   ---------------------------
#      | X |   | X | O |   | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 4
# it is X's turn, please choose a move
#
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   | O |   |   |
#   ---------------------------
#      |   |   | X |   |   |
#   ---------------------------
#      | O |   | X |   |   |
#   ---------------------------
#      | X |   | X | O |   | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 2
# it is X's turn, please choose a move
#
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   | O |   |   |
#   ---------------------------
#      | X |   | X |   |   |
#   ---------------------------
#      | O |   | X |   |   |
#   ---------------------------
#      | X | O | X | O |   | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 1
# it is X's turn, please choose a move
#
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   | O |   |   |
#   ---------------------------
#      | X |   | X |   |   |
#   ---------------------------
#      | O | O | X |   |   |
#   ---------------------------
#    X | X | O | X | O |   | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 3
# it is X's turn, please choose a move
#
#      |   |   |   |   |   |
#   ---------------------------
#      |   |   |   |   |   |
#   ---------------------------
#      |   | O | O |   |   |
#   ---------------------------
#      | X | X | X |   |   |
#   ---------------------------
#      | O | O | X |   |   |
#   ---------------------------
#    X | X | O | X | O |   | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 4
# it is X's turn, please choose a move
#
#      |   |   |   |   |   |
#   ---------------------------
#      |   | O | X |   |   |
#   ---------------------------
#      |   | O | O |   |   |
#   ---------------------------
#      | X | X | X |   |   |
#   ---------------------------
#      | O | O | X |   |   |
#   ---------------------------
#    X | X | O | X | O |   | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 4
# it is X's turn, please choose a move
#
#      |   |   | X |   |   |
#   ---------------------------
#      |   | O | X |   |   |
#   ---------------------------
#      | O | O | O |   |   |
#   ---------------------------
#      | X | X | X |   |   |
#   ---------------------------
#      | O | O | X |   |   |
#   ---------------------------
#    X | X | O | X | O |   | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 3
# it is X's turn, please choose a move
#
#      |   | X | X |   |   |
#   ---------------------------
#      | O | O | X |   |   |
#   ---------------------------
#      | O | O | O |   |   |
#   ---------------------------
#      | X | X | X |   |   |
#   ---------------------------
#      | O | O | X |   |   |
#   ---------------------------
#    X | X | O | X | O |   | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 2
# it is X's turn, please choose a move
#
#      | X | X | X |   |   |
#   ---------------------------
#      | O | O | X |   |   |
#   ---------------------------
#      | O | O | O |   |   |
#   ---------------------------
#      | X | X | X |   |   |
#   ---------------------------
#      | O | O | X |   |   | O
#   ---------------------------
#    X | X | O | X | O |   | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 7
# it is X's turn, please choose a move
#
#      | X | X | X |   |   |
#   ---------------------------
#      | O | O | X |   |   |
#   ---------------------------
#      | O | O | O |   |   | O
#   ---------------------------
#      | X | X | X |   |   | X
#   ---------------------------
#      | O | O | X |   |   | O
#   ---------------------------
#    X | X | O | X | O |   | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 7
# it is X's turn, please choose a move
#
#      | X | X | X |   |   |
#   ---------------------------
#      | O | O | X |   |   | X
#   ---------------------------
#      | O | O | O |   |   | O
#   ---------------------------
#      | X | X | X |   |   | X
#   ---------------------------
#      | O | O | X |   |   | O
#   ---------------------------
#    X | X | O | X | O | O | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 6
# it is X's turn, please choose a move
#
#      | X | X | X |   |   |
#   ---------------------------
#      | O | O | X |   |   | X
#   ---------------------------
#      | O | O | O |   |   | O
#   ---------------------------
#      | X | X | X |   | O | X
#   ---------------------------
#      | O | O | X |   | X | O
#   ---------------------------
#    X | X | O | X | O | O | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 6
# it is X's turn, please choose a move
#
#      | X | X | X |   |   | O
#   ---------------------------
#      | O | O | X |   |   | X
#   ---------------------------
#      | O | O | O |   | X | O
#   ---------------------------
#      | X | X | X |   | O | X
#   ---------------------------
#      | O | O | X |   | X | O
#   ---------------------------
#    X | X | O | X | O | O | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 6
# it is X's turn, please choose a move
#
#      | X | X | X |   | O | O
#   ---------------------------
#      | O | O | X |   | X | X
#   ---------------------------
#      | O | O | O |   | X | O
#   ---------------------------
#      | X | X | X |   | O | X
#   ---------------------------
#      | O | O | X |   | X | O
#   ---------------------------
#    X | X | O | X | O | O | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 1
# it is X's turn, please choose a move
#
#      | X | X | X |   | O | O
#   ---------------------------
#      | O | O | X |   | X | X
#   ---------------------------
#      | O | O | O |   | X | O
#   ---------------------------
#    O | X | X | X |   | O | X
#   ---------------------------
#    X | O | O | X |   | X | O
#   ---------------------------
#    X | X | O | X | O | O | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 1
# it is X's turn, please choose a move
#
#      | X | X | X |   | O | O
#   ---------------------------
#      | O | O | X |   | X | X
#   ---------------------------
#    X | O | O | O |   | X | O
#   ---------------------------
#    O | X | X | X |   | O | X
#   ---------------------------
#    X | O | O | X | O | X | O
#   ---------------------------
#    X | X | O | X | O | O | O
#   ---------------------------
#    1 | 2 | 3 | 4 | 5 | 6 | 7
#
# 5

# %%
f = open('TD_connect_four.txt','w')

for item in epoch_objective_list:
    print>>f , item

# %%
for i in range(10):
    print training_data[i],target_data[i],value_fun(training_data[i].reshape(1,42))

# %% [markdown]
# # Supervised Learning

# %%
raw_training = pd.read_csv('connect-4.csv',header = None)

# %%
training_set = []
targets_set = []
for index,row in raw_training.iterrows():
    input_dict = {'b':0,'x':1,'o':-1}
    game_state_dict = {'win':1,'draw':0,'loss':-1}
    game_state = game_state_dict[row[42]]
    row = row[:-1].apply(lambda x: input_dict[x])
    board = np.flipud(np.reshape(np.array(row),(6,7),order = 'F'))
    if np.sum(board)==1:
        board = -1 * np.copy(board)
    
    training_set.append(np.copy(board).reshape(1,42))
    targets_set.append(game_state)

dummy_list = list(zip(training_set,targets_set))
random.shuffle(dummy_list)
training_set,targets_set = zip(*dummy_list)

val_training_set = training_set[:len(training_set)/2]
val_targets_set = targets_set[:len(targets_set)/2]
training_set = training_set[len(training_set)/2:]
targets_set = targets_set[len(targets_set)/2:]

# %%
X_sym = T.matrix()
y_sym = T.matrix()

output = lasagne.layers.get_output(value_out,X_sym)
output_det = lasagne.layers.get_output(value_out,X_sym,deterministic=True)
value_fun = theano.function([X_sym],output)
value_fun_det = theano.function([X_sym],output_det)
params = lasagne.layers.get_all_params(value_out)
objective = T.mean(lasagne.objectives.squared_error(output,y_sym))
grad = T.grad(objective,params)

# %%
BATCH_SIZE = 256
train_duration = 500
minimax_str = 0
validation_str = 2
valid_freq = 100
learning_speed = 0.01
updates = lasagne.updates.nesterov_momentum(grad, params, learning_rate=learning_speed,momentum = 0.9)
#updates = lasagne.updates.sgd(grad, params, learning_rate=learning_speed)
train_net = theano.function([X_sym, y_sym], objective, updates=updates)
val_net = theano.function([X_sym, y_sym], objective)

# %%
t0 = time.clock()

epoch_objective_list = []

for epoch in range(train_duration):


    t2=time.clock()

    objectives = []
    index_pool = range(len(targets_set))
    random.shuffle(index_pool)
    while len(index_pool) > BATCH_SIZE:
        
        sample_indices = [index_pool.pop() for _ in xrange(BATCH_SIZE)]

        targets = np.zeros((BATCH_SIZE,1))
        training = np.zeros((BATCH_SIZE,42))
        for k in range(BATCH_SIZE):
            training[k] = np.copy(training_set[sample_indices[k]])
            targets[k] = targets_set[sample_indices[k]]

        objectives.append(train_net(training,targets))
        #break to only do 1 batch per run.
    objective_total = np.mean(objectives)


    objectives = []
    index_pool = range(len(val_targets_set))
    random.shuffle(index_pool)
    while len(index_pool) > BATCH_SIZE:
        
        sample_indices = [index_pool.pop() for _ in xrange(BATCH_SIZE)]

        targets = np.zeros((BATCH_SIZE,1))
        training = np.zeros((BATCH_SIZE,42))
        for k in range(BATCH_SIZE):
            training[k] = np.copy(training_set[sample_indices[k]])
            targets[k] = targets_set[sample_indices[k]]

        objectives.append(val_net(training,targets))
        #break to only do 1 batch per run.
    val_total = np.mean(objectives)

    print (('Epoch {:5d},objective: {:0.5f}, validation: {:0.5f}, step duration: {:1.3f}s').format(
            epoch,float(objective_total),float(val_total),time.clock()-t2))
    
        
    
    
    
    epoch_objective_list.append([epoch,objective_total,val_total])

    # print 'epoch duration {:2.2f}s'.format(time.clock()-t2)
    if epoch%valid_freq==0:
        print ' '
        print ' '
        test_result = {'wins':0,'ties':0,'losses':0}
        for j in range(100):
            result = cccc.play(nn_ai(value_fun_det,'value'),alpha_beta(validation_str))
            if result.winner ==1:
                test_result['wins'] +=1
            if result.winner == 0:
                test_result['ties'] +=1
            if result.winner == -1:
                test_result['losses'] +=1


        print 'As X, neural network has a score of {:3d}-{:3d}-{:3d} vs {}-depth minimax'.format(test_result['wins'],
                                                               test_result['ties'],test_result['losses'],validation_str)

        test_result = {'wins':0,'ties':0,'losses':0}

        for j in range(100):
            result = cccc.play(alpha_beta(validation_str),nn_ai(value_fun_det,'value'))
            if result.winner ==1:
                test_result['losses'] +=1
            if result.winner == 0:
                test_result['ties'] +=1
            if result.winner == -1:
                test_result['wins'] +=1

        print 'As O, neural network has a score of {:3d}-{:3d}-{:3d} vs {}-depth minimax'.format(test_result['wins'],
                                                            test_result['ties'],test_result['losses'],validation_str)
        print ' '
        print 'elapsed time: {:3.3f}s'.format(time.clock()-t0)
        print ' '
        
        


print('\n')

#for epoch in range(10):

        
#    t_epoch = time.clock()

#    result_list = [tourney(output) for i in range(BATCH_SIZE)]
#    fitness_list = [fitness(result) for result in result_list]
    
#    score= f_train(fitness_list)
       
#    t1=time.clock()-t_epoch
    
#    print('Epoch {}, duration {:.01f} seconds'.format(
#            epoch+1, t1))
#    print('Record is: {}-{}-{} with a score of {}'.format(sum([result['wins'] for result in result_list]),
#                                                          sum([result['ties'] for result in result_list]),
#                                                          sum([result['losses'] for result in result_list]),
#                                                          sum([fitness for fitness in fitness_list])))
#    print('mean score is {}'.format(score))
print('total time for neural network is {:.01f} seconds'.format(time.clock()-t0))

# %%
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline

f = open('supervised_connect_four.txt','r')
plot_list = f.read().splitlines()
plot_list = np.array([[float(x) for x in item[1:-1].split(',')] for item in plot_list])

f = open('supervised_tictactoe.txt','r')
plot_list2 = f.read().splitlines()
plot_list2 = np.array([[float(x) for x in item[1:-1].split(',')] for item in plot_list2])

# %%
plt.figure(figsize=(16,9))
plt.plot(plot_list[:,0],plot_list[:,1],color = 'blue',linewidth=3)
plt.plot(plot_list[:,0],plot_list[:,2],color = 'green')
# plt.plot(50*plot_list2[:,0]+plot_list2[:,1]-900,plot_list2[:,2],color = 'red')
plt.title('Deep Learning',fontsize=32)
plt.xlabel('Epoch',fontsize=24)
plt.ylabel('Mean Squared Error',fontsize = 24)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
# ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
# ax.spines["left"].set_visible(False)    
  
# Ensure that the axis ticks only show up on the bottom and left of the plot.    
# Ticks on the right and top of the plot are generally unnecessary chartjunk.    
ax.get_xaxis().tick_bottom()    
ax.get_yaxis().tick_left()
plt.text(100, 0.31,"Supervised learning with connect four - training",fontsize=20,color='blue')
plt.text(100, 0.36,"Supervised learning with connect four - validation",fontsize=20,color='green')
# plt.text(410, 0.51,"Reinforcement learning with tic tac toe - loss",fontsize=20,color='red')
plt.savefig('supervised_c4_new.png')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
f = open('TD_connect_four.txt','r')
plot_list = f.read().splitlines()
plot_list = np.array([[float(x) for x in item[1:-1].split(',')] for item in plot_list])

# %%
plt.plot(500*plot_list[:,0]+plot_list[:,1],plot_list[:,2])
plt.show

# %%
f = open('supervised_tictactoe.txt','r')
plot_list = f.read().splitlines()
plot_list = np.array([[float(x) for x in item[1:-1].split(',')] for item in plot_list])

# %%
plt.figure(figsize=(16,9))
plt.plot(50*plot_list[:,0]+plot_list[:,1],plot_list[:,2],color = 'red')
plt.title('Reinforcement Learning for Tic Tac Toe',fontsize=32)
plt.xlabel('Epoch',fontsize=24)
plt.ylabel('Mean Squared Error',fontsize = 24)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
# ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
# ax.spines["left"].set_visible(False)    
ax.get_xaxis().tick_bottom()    
ax.get_yaxis().tick_left()
plt.subplots_adjust(bottom = 0.2, left = 0.2)
plt.savefig('reinforcement_ttt.png')
plt.show
# Out:
# <function matplotlib.pyplot.show>
